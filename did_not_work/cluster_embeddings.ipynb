# %%
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
title_embeds = np.load('data/title_embeds.npy')

# %%
tsne = TSNE(n_components=2)
title_embeds_transformed = tsne.fit_transform(title_embeds)

# %%
title_embeds_transformed = tsne.transform(title_embeds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-262f3d42471c> in <module>
# ----> 1 title_embeds_transformed = tsne.transform(title_embeds)
#
# AttributeError: 'TSNE' object has no attribute 'transform'

# %%
clustering = DBSCAN()

# %%
clusters = clustering.fit_predict(title_embeds)

# %%
plt.scatter(title_embeds_transformed[:,0], title_embeds_transformed[:,1], s= 0.1)

# %%
2+2

# %%
2+2
